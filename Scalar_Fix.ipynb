# %% [markdown]
# 1. melakukan berbagai operasi yg dicontohkan menggunakan python

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
#(Pake angka terakhir NPM)
x = 115

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 15

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x + y
sum = x + y
sum
# Out:
# 130

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 115.5

# %%
# jumlahkan x_float dengan y
sum = x_float + y
sum
# Out:
# 130.5

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_tf = tf.Variable(115)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=115>

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_tf = tf.Variable(15)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=15>

# %%
# jumlahkan x + y
sum_tf = x_tf + y_tf
sum_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=130>

# %%
#  buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_tf = tf.Variable(115.5)
x_float_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=115.5>

# %% [markdown]
# 3. lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch

# %%
# buat variabel x_pt dan suatu nilai tensor
x_pt = torch.tensor(115, dtype = torch.int32)
x_pt
# Out:
# tensor(115, dtype=torch.int32)

# %%
# tampilkan tipe data dari x_pt
x_pt = torch.tensor(115, dtype = torch.int32)
x_pt
# Out:
# tensor(115, dtype=torch.int32)

# %%
# buat variabel y_pt dan suatu nilai tensor
y_pt = torch.tensor(15, dtype = torch.int32)
y_pt
# Out:
# tensor(15, dtype=torch.int32)

# %%
# tampilkan tipe data dari y_pt
y_pt = torch.tensor(15, dtype = torch.int32)
y_pt
# Out:
# tensor(15, dtype=torch.int32)

# %%
# jumlahkan x_pt + y_pt
sum_pt = x_pt + y_pt
sum_pt
# Out:
# tensor(130, dtype=torch.int32)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_pt_float = torch.tensor(115.5, dtype = torch.float32)
x_pt_float
# Out:
# tensor(115.5000)

# %%
# jumlahkan x_pt_float dengan y_pt
sum_pt = x_pt_float + y_pt
sum_pt
# Out:
# tensor(130.5000)

# %%
# tampilkan tipe data dari x_pt_float
x_pt_float = torch.tensor(115.5, dtype = torch.float32)
x_pt_float
# Out:
# tensor(115.5000)
