# %% [markdown]
# 1. Selesaikan soal berikut

# %%
import numpy as np

# %%
# what is the tranpose of this vector
x = np.array([[25], [2], [-3], [-23]])
x
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
# transpose dari x
x_t = x.T
x_t
# Out:
# array([[ 25,   2,  -3, -23]])
